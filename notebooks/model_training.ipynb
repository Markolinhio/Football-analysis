# %%
import os
import sys
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from pathlib import Path
import cv2
import pickle
import numpy as np
import matplotlib.pyplot as plt
import math
import json
from datetime import date
plt.rcParams["figure.figsize"] = (24,18)

from ultralytics import YOLO
from utils import *

import torch
torch.cuda.empty_cache()

# %%
os.path.dirname(os.getcwd())
# Out:
# '/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis'

# %%
# Load original, pretrained model
model_path = os.path.join(os.path.dirname(os.getcwd()), 'models')
print(os.path.exists(os.path.join(model_path, "yolov8n.pt")))
model = YOLO(os.path.join(model_path, "yolov8n.pt"))
# Out:
# True

# %%
# Load coco dataset
data_path = os.path.join(os.path.dirname(os.getcwd()), 'data')
print(data_path)
dataset_name = 'merge_train_fixed'
coco_dataset_path = os.path.join(data_path, 'coco_datasets/'+dataset_name)
coco_file_path = os.path.join(coco_dataset_path, 'annotations/instances_default.json')
images_file_path = os.path.join(coco_file_path, 'images')
# Out:
# /media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data

# %%
convert_data = True
if convert_data:
    coco2yolo(coco_dataset_path)

# %%
results = model.train(data=os.path.join(data_path, 'coco_datasets/merge_train_fixed_yolov8/data.yaml'), 
                      #batch=-1,
                      epochs=100, 
                      #imgsz=736,
                      verbose=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.149 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080, 9987MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/models/yolov8n.pt, data=/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/data.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train38
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 225 layers, 3011238 parameters, 3011222 gradients
#
# Transferred 319/355 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/labels.cache... 144 images, 0 backgrounds, 0 corrupt: 100%|██████████| 144/144 [00:00<?, ?it/s]
# val: Scanning /media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/valid/labels.cache... 37 images, 0 backgrounds, 0 corrupt: 100%|██████████| 37/37 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train38/labels.jpg...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train38
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.57G      1.504      3.944     0.9594        423        640: 100%|██████████| 9/9 [00:02<00:00,  3.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.70it/s]
#                    all         37        697     0.0569      0.452     0.0711     0.0413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.89G      1.414      2.166      0.903        534        640: 100%|██████████| 9/9 [00:00<00:00, 12.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.24it/s]
#                    all         37        697     0.0451      0.462      0.354      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.41G      1.351       1.03     0.8989        502        640: 100%|██████████| 9/9 [00:00<00:00, 12.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.53it/s]
#                    all         37        697      0.985      0.293      0.429      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.49G      1.386     0.9498      0.898        708        640: 100%|██████████| 9/9 [00:00<00:00, 13.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.29it/s]
#                    all         37        697      0.884      0.407      0.429      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.37G      1.385     0.9333     0.9075        632        640: 100%|██████████| 9/9 [00:00<00:00, 13.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 18.45it/s]
#                    all         37        697      0.975      0.288      0.448       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.73G      1.325     0.8675      0.897        585        640: 100%|██████████| 9/9 [00:00<00:00, 13.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 18.72it/s]
#                    all         37        697      0.965      0.334      0.447      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.74G      1.306     0.8539     0.8854        486        640: 100%|██████████| 9/9 [00:00<00:00, 13.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 16.70it/s]
#                    all         37        697      0.974       0.37      0.461      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.76G      1.405     0.8564     0.8924        642        640: 100%|██████████| 9/9 [00:00<00:00, 13.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 16.82it/s]
#                    all         37        697      0.963      0.388      0.457      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.34G        1.3     0.8275     0.8909        492        640: 100%|██████████| 9/9 [00:00<00:00, 13.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 16.22it/s]
#                    all         37        697       0.97      0.441      0.468      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.79G      1.398     0.8417     0.8958        467        640: 100%|██████████| 9/9 [00:00<00:00, 13.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 16.65it/s]
#                    all         37        697      0.966      0.444      0.475      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.59G      1.334     0.8141     0.8795        530        640: 100%|██████████| 9/9 [00:00<00:00, 13.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.42it/s]
#                    all         37        697      0.969      0.448      0.475      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.48G      1.267     0.7911     0.8919        573        640: 100%|██████████| 9/9 [00:00<00:00, 13.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.85it/s]
#                    all         37        697      0.972      0.456      0.481      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.46G       1.24      0.773     0.8995        539        640:  44%|████▍     | 4/9 [00:00<00:00, 13.21it/s][ WARN:0@21.950] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000273.png'): can't open/read file: check file path/integrity
#      13/100      2.65G      1.245     0.7715     0.8961        518        640:  44%|████▍     | 4/9 [00:00<00:00, 13.21it/s][ WARN:0@21.974] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000306.png'): can't open/read file: check file path/integrity
#      13/100      2.65G       1.26     0.7711     0.8941        639        640:  67%|██████▋   | 6/9 [00:00<00:00, 13.19it/s][ WARN:0@22.038] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000144.png'): can't open/read file: check file path/integrity
#      13/100      2.65G      1.274     0.7775     0.8934        587        640:  67%|██████▋   | 6/9 [00:00<00:00, 13.19it/s][ WARN:0@22.125] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000001795.png'): can't open/read file: check file path/integrity
#      13/100      2.65G      1.275      0.776     0.8914        559        640:  89%|████████▉ | 8/9 [00:00<00:00, 12.97it/s][ WARN:0@22.194] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000001969.png'): can't open/read file: check file path/integrity
#      13/100      2.65G      1.272     0.7746     0.8906        509        640: 100%|██████████| 9/9 [00:00<00:00, 13.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s][ WARN:0@22.260] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/valid/images/000000000019.png'): can't open/read file: check file path/integrity
# [ WARN:0@22.354] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/valid/images/000000000225.png'): can't open/read file: check file path/integrity
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.29it/s]
#                    all         37        697      0.974      0.451      0.481      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/9 [00:00<?, ?it/s][ WARN:0@22.542] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000186.png'): can't open/read file: check file path/integrity
#      14/100      2.17G      1.209     0.7592     0.9066        501        640:   0%|          | 0/9 [00:00<?, ?it/s][ WARN:0@22.635] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000002413_1.png'): can't open/read file: check file path/integrity
#      14/100       2.3G      1.217     0.7641     0.8981        471        640:  22%|██▏       | 2/9 [00:00<00:00, 13.93it/s][ WARN:0@22.736] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000126.png'): can't open/read file: check file path/integrity
#      14/100      2.46G      1.217      0.758     0.8997        489        640:  22%|██▏       | 2/9 [00:00<00:00, 13.93it/s][ WARN:0@22.816] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000273.png'): can't open/read file: check file path/integrity
#      14/100      2.46G      1.206     0.7554     0.8971        447        640:  44%|████▍     | 4/9 [00:00<00:00, 13.57it/s][ WARN:0@22.829] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000009.png'): can't open/read file: check file path/integrity
#      14/100      2.62G      1.226      0.753     0.8932        689        640:  44%|████▍     | 4/9 [00:00<00:00, 13.57it/s][ WARN:0@22.917] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000848.png'): can't open/read file: check file path/integrity
#      14/100      2.62G      1.212     0.7486     0.8893        520        640:  67%|██████▋   | 6/9 [00:00<00:00, 13.92it/s][ WARN:0@22.989] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000621.png'): can't open/read file: check file path/integrity
#      14/100      2.62G      1.223     0.7472     0.8865        655        640:  67%|██████▋   | 6/9 [00:00<00:00, 13.92it/s][ WARN:0@23.049] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000332_dup.png'): can't open/read file: check file path/integrity
#      14/100      2.81G      1.235     0.7469     0.8849        665        640:  89%|████████▉ | 8/9 [00:00<00:00, 13.69it/s][ WARN:0@23.123] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000201_dup.png'): can't open/read file: check file path/integrity
#      14/100      2.81G      1.239     0.7499     0.8862        524        640: 100%|██████████| 9/9 [00:00<00:00, 13.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s][ WARN:0@23.199] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/valid/images/000000000019.png'): can't open/read file: check file path/integrity
# [ WARN:0@23.292] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/valid/images/000000000225.png'): can't open/read file: check file path/integrity
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 17.61it/s]
#                    all         37        697      0.968      0.463      0.484      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/9 [00:00<?, ?it/s][ WARN:0@23.552] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000296.png'): can't open/read file: check file path/integrity
#      15/100       2.2G      1.282     0.7606     0.8786        712        640:   0%|          | 0/9 [00:00<?, ?it/s][ WARN:0@23.631] global loadsave.cpp:248 findDecoder imread_('/media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/data/coco_datasets/merge_train_fixed_yolov8/train/images/000000000144.png'): can't open/read file: check file path/integrity
#      15/100       2.2G      1.282     0.7606     0.8786        712        640:  11%|█         | 1/9 [00:00<00:01,  6.59it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /media/khoa-ys/Personal/Projects/Football Analysis/Football-analysis/notebooks/model_training.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/media/khoa-ys/Personal/Projects/Football%20Analysis/Football-analysis/notebooks/model_training.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> results = model.train(data=os.path.join(data_path, 'coco_datasets/merge_train_fixed_yolov8/data.yaml'),
#       <a href='vscode-notebook-cell:/media/khoa-ys/Personal/Projects/Football%20Analysis/Football-analysis/notebooks/model_training.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>                       #batch=-1,
#       <a href='vscode-notebook-cell:/media/khoa-ys/Personal/Projects/Football%20Analysis/Football-analysis/notebooks/model_training.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>                       epochs=100,
#       <a href='vscode-notebook-cell:/media/khoa-ys/Personal/Projects/Football%20Analysis/Football-analysis/notebooks/model_training.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>                       #imgsz=736,
#       <a href='vscode-notebook-cell:/media/khoa-ys/Personal/Projects/Football%20Analysis/Football-analysis/notebooks/model_training.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>                       verbose=True)
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/ultralytics/engine/model.py:377, in Model.train(self, trainer, **kwargs)
#     375     self.model = self.trainer.model
#     376 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 377 self.trainer.train()
#     378 # Update model and cfg after training
#     379 if RANK in (-1, 0):
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:192, in BaseTrainer.train(self)
#     190         ddp_cleanup(self, str(file))
#     191 else:
# --> 192     self._do_train(world_size)
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:343, in BaseTrainer._do_train(self, world_size)
#     341 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     342 if ni - last_opt_step >= self.accumulate:
# --> 343     self.optimizer_step()
#     344     last_opt_step = ni
#     346 # Log
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:462, in BaseTrainer.optimizer_step(self)
#     460 self.scaler.unscale_(self.optimizer)  # unscale gradients
#     461 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)  # clip gradients
# --> 462 self.scaler.step(self.optimizer)
#     463 self.scaler.update()
#     464 self.optimizer.zero_grad()
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:341, in GradScaler.step(self, optimizer, *args, **kwargs)
#     337     self.unscale_(optimizer)
#     339 assert len(optimizer_state["found_inf_per_device"]) > 0, "No inf checks were recorded for this optimizer."
# --> 341 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     343 optimizer_state["stage"] = OptState.STEPPED
#     345 return retval
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:287, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     285 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     286     retval = None
# --> 287     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     288         retval = optimizer.step(*args, **kwargs)
#     289     return retval
#
# File ~/Projects/venv_for_projects/football_analysis_venv/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:287, in <genexpr>(.0)
#     285 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     286     retval = None
# --> 287     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     288         retval = optimizer.step(*args, **kwargs)
#     289     return retval
#
# KeyboardInterrupt:
